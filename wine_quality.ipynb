# %% [markdown]
# <a href="https://colab.research.google.com/github/GulkoA/GrapeIO/blob/main/wine_quality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
wine = pd.read_csv("train.csv")

# %%
wine
# Out:
#         Id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        0            8.0              0.50         0.39            2.20
# 1        1            9.3              0.30         0.73            2.30
# 2        2            7.1              0.51         0.03            2.10
# 3        3            8.1              0.87         0.22            2.60
# 4        4            8.5              0.36         0.30            2.30
# ...    ...            ...               ...          ...             ...
# 2051  2051            6.6              0.31         0.13            2.00
# 2052  2052            9.7              0.59         0.21            1.80
# 2053  2053            7.7              0.43         0.42            1.70
# 2054  2054            9.1              0.50         0.00            1.75
# 2055  2055            6.2              0.31         0.18            2.30
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
print("# of unique value in each column\n")
# Finding the number of unique values present in each column
for col in wine:
    print(col,': ',(len(pd.unique(wine[col]))))
# Out:
# # of unique value in each column
#
# Id :  2056
# fixed acidity :  87
# volatile acidity :  113
# citric acid :  71
# residual sugar :  66
# chlorides :  103
# free sulfur dioxide :  49
# total sulfur dioxide :  126
# density :  313
# pH :  77
# sulphates :  73
# alcohol :  53
# quality :  6

# %%
train_null_val={}
train_null_val=wine.isna().sum()
print("# of null values in each column\n")
print(train_null_val)
# Out:
# # of null values in each column
#
# Id                      0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.scatterplot(data = wine, x=wine["fixed acidity"], y=wine["quality"])

# %%
sns.scatterplot(data = wine, x=wine["volatile acidity"], y=wine["quality"])

# %%
sns.scatterplot(data = wine, x=wine["citric acid"], y=wine["quality"])

# %%
sns.scatterplot(data = wine, x=wine["residual sugar"], y=wine["quality"])

# %%
sns.scatterplot(data = wine, x=wine["chlorides"], y=wine["quality"])

# %%
sns.scatterplot(data = wine, x=wine["free sulfur dioxide"], y=wine["quality"])

# %%
sns.scatterplot(data = wine, x=wine["total sulfur dioxide"], y=wine["quality"])

# %%
sns.scatterplot(data = wine, x=wine["density"], y=wine["quality"])

# %%
sns.scatterplot(data = wine, x=wine["pH"], y=wine["quality"])

# %%
import plotly.express as px

# %%
fig = px.imshow(wine.corr() ,text_auto=True, aspect="auto" , color_continuous_scale = "viridis")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
